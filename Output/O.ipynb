# %%
import numpy as np
import pandas as pd
import re
pd.set_option('display.max_columns', None)

# %%
new_df = pd.read_csv(r"C:\Users\manue\OneDrive\Escritorio\Ironhack\Project Sharks\Input\new_df.csv", encoding= "ISO-8859-1")

# %%
new_df.head()
# Out:
#      country             area                        location activity_clean  \
# 0        USA       California     Oceanside, San Diego County         others
# 1        USA          Georgia  St. Simon Island, Glynn County       swimming
# 2        USA           Hawaii                    Habush, Oahu        surfing
# 3  AUSTRALIA  New South Wales              Arrawarra Headland        surfing
# 4     MEXICO           Colima                        La Ticla         diving
#
#          type fatal                                             injury  \
# 0        Boat     N  No injury to occupant, outrigger canoe and pad...
# 1  Unprovoked     N                         Minor injury to left thigh
# 2     Invalid     N       Injury to left lower leg from surfboard skeg
# 3  Unprovoked     N                          Minor injury to lower leg
# 4    Provoked     N  Lacerations to leg & hand shark PROVOKED INCIDENT
#
#        species_clean date_clean        name_clean  original_order_clean  \
# ...
